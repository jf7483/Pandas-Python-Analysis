# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Exercise 2 - Filtering
# Return the following subsets of the dataframe.
#
# How many listings are there with a price less than 100?
# Find how many listings there are in just Brooklyn.
# Find how many listings there are in Brooklyn with a price less than 100.
# Using .isin() select anyone that has the host name of Michael, David, John, and Daniel.
# Count the amout of names each time appears.
# Create a new column called adjusted_price that has $100 added to every listing in Williamsburg. The prices for all other listings should be the same as the were before.
# What % of the rooms are private, and what % of the rooms are shared.
# Hint, use .value_counts()
# Challenge:
#
# Listings with the word brownstone in the name (hint to come, might move this one later if needed)
# hint... build a function to check for 'brownstone' and apply that function OR df.name.str.????

# %% [markdown]
# ## How many listings are ther with a price less than 100?

# %%
df = pd.read_csv("listings.csv")
df.head()
# Out:
#      id                                               name  host_id  \
# 0  2595                              Skylit Midtown Castle     2845
# 1  3831  Whole flr w/private bdrm, bath & kitchen(pls r...     4869
# 2  5121                                    BlissArtsSpace!     7356
# 3  5136           Spacious Brooklyn Duplex, Patio + Garden     7378
# 4  5178                   Large Furnished Room Near B'way　     8967
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0     Jennifer           Manhattan             Midtown  40.75362  -73.98377
# 1  LisaRoxanne            Brooklyn        Clinton Hill  40.68514  -73.95976
# 2        Garon            Brooklyn  Bedford-Stuyvesant  40.68688  -73.95596
# 3      Rebecca            Brooklyn         Sunset Park  40.66120  -73.99423
# 4     Shunichi           Manhattan      Hell's Kitchen  40.76489  -73.98493
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
condition = df['price'] < 100
df[condition].head()
df[condition]['id'].count()
# Out:
# 22778

# %% [markdown]
# ## How many listings are there in Brooklyn?

# %%
df_bk = pd.read_csv("listings.csv")

condition2 = df_bk['neighbourhood_group'] == 'Brooklyn'
df_bk[condition2].head()
# Out:
#       id                                               name  host_id  \
# 1   3831  Whole flr w/private bdrm, bath & kitchen(pls r...     4869
# 2   5121                                    BlissArtsSpace!     7356
# 3   5136           Spacious Brooklyn Duplex, Patio + Garden     7378
# 8   5803     Lovely Room 1, Garden, Best Area, Legal rental     9744
# 11  6848                   Only 2 stops to Manhattan studio    15991
#
#         host_name neighbourhood_group       neighbourhood  latitude  \
# 1     LisaRoxanne            Brooklyn        Clinton Hill  40.68514
# 2           Garon            Brooklyn  Bedford-Stuyvesant  40.68688
# 3         Rebecca            Brooklyn         Sunset Park  40.66120
# 8          Laurie            Brooklyn         South Slope  40.66829
# 11  Allen & Irina            Brooklyn        Williamsburg  40.70837
#
#     longitude        room_type  price  minimum_nights  number_of_reviews  \
# ...

# %%
df_bk[condition2]['neighbourhood_group'].count()
# Out:
# 18632

# %% [markdown]
# ## Find how many listings there are in Brooklyn with a price less than 100

# %%
condition2 = df['neighbourhood_group'] == 'Brooklyn'
condition = df['price'] < 100

df[condition & condition2]['id'].count()
# Out:
# 10473

# %% [markdown]
# ## Using `.isin()` select anyone that has the host name of Michael, David, John, and Daniel.##

# %%
host_name = ['Michael', 'David', 'John', 'Daniel']

condition = df.host_name.isin(host_name)

df[condition].head()
# Out:
#         id                                               name  host_id  \
# 52   16595  LOFT HAVEN ~ Six Windows ~ Bricks ~ Plants ~ Q...    64522
# 201  61747              Cozy,  Brooklyn, Prospect Park Studio   299370
# 209  62903  Beautiful modern studio apartment in heart of NYC   306605
# 220  64015                       Prime East Village 1 Bedroom   146944
# 260  74073       Food & Music Dream Apartment in Williamsburg   211877
#
#     host_name neighbourhood_group              neighbourhood  latitude  \
# 52     Daniel            Brooklyn               Williamsburg  40.70933
# 201     David            Brooklyn  Prospect-Lefferts Gardens  40.65979
# 209    Daniel           Manhattan                    Chelsea  40.74238
# 220     David           Manhattan               East Village  40.72807
# 260    Daniel            Brooklyn               Williamsburg  40.71113
#
#      longitude        room_type  price  minimum_nights  number_of_reviews  \
# ...

# %% [markdown]
# ## 5. Create a new column called `adjusted_price` that has $100 added to every listing in Williamsburg. The prices for all other listings should be the same as the were before

# %%
df['adjusted_price'] = np.where(c1, df['price'] + 100, df['price'])
df
# Out:
#              id                                               name    host_id  \
# 0          2595                              Skylit Midtown Castle       2845
# 1          3831  Whole flr w/private bdrm, bath & kitchen(pls r...       4869
# 2          5121                                    BlissArtsSpace!       7356
# 3          5136           Spacious Brooklyn Duplex, Patio + Garden       7378
# 4          5178                   Large Furnished Room Near B'way　       8967
# ...         ...                                                ...        ...
# 46522  44807522         Designer Gramercy Studio Townhouse by UNSQ   12941925
# 46523  44807786  Cozy & comfy apt in the heart of Inwood Manhattan  284790520
# 46524  44811717  Comfortable safe environment 24hr security camera  362453686
# 46525  44814944                 Upper West Side studio 86th Street    4039777
# 46526  44818009  5MIN D/N trains, NEAR THE BEACH, 50’ TO MANHATTAN   48098268
#
# ...

# %% [markdown]
# ## 6. What % of the rooms are private, and what % of the rooms are shared.

# %%
c2 = df['room_type'] == 'Private room'

df[c2]['room_type'].count()/df['room_type'].count() *100
# Out:
# 45.444580566122895

# %%
c3 = df['room_type'] == 'Shared room'

df[c3]['room_type'].count()/df['room_type'].count() *100
# Out:
# 2.12134889419047
