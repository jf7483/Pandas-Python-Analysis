# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Using NYC Open Data

# %%
# url = 'https://data.cityofnewyork.us/resource/6z8x-wfk4.csv'

evictions_df = pd.read_csv('Evictions.csv')

# %%
evictions_df.head()
# Out:
#   COURT_INDEX_NUMBER  DOCKET_NUMBER      EVICTION_ADDRESS EVICTION_APT_NUM  \
# 0           5743/19B          92057  1226 ROSEDALE AVENUE               3F
# 1          B31724/17          99191    2146 WATSON AVENUE               1R
# 2         K64166/16B          92592        55 WINTHROP ST               5D
# 3          Q62200/18         109351     41-05 74TH STREET              1-D
# 4         K071827/17         389794   732 ST MARKS AVENUE               14
#
#   EXECUTED_DATE MARSHAL_FIRST_NAME MARSHAL_LAST_NAME  \
# 0    07/18/2019             Justin          Grossman
# 1    05/14/2018            Darlene            Barone
# 2    03/29/2017            Darlene            Barone
# 3    11/15/2018            Darlene            Barone
# 4    02/13/2018            Richard             McCoy
#
#   RESIDENTIAL_COMMERCIAL_IND   BOROUGH  EVICTION_ZIP
# 0                Residential     BRONX         10472
# 1                Residential     BRONX         10472
# 2                Residential  BROOKLYN         11225
# 3                Residential    QUEENS         11373
# 4                Residential  BROOKLYN         11216

# %%
# checking to see what type is each column and to see which are NULL 
evictions_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66349 entries, 0 to 66348
# Data columns (total 10 columns):
# COURT_INDEX_NUMBER            66349 non-null object
# DOCKET_NUMBER                 66349 non-null int64
# EVICTION_ADDRESS              66349 non-null object
# EVICTION_APT_NUM              55378 non-null object
# EXECUTED_DATE                 66349 non-null object
# MARSHAL_FIRST_NAME            66349 non-null object
# MARSHAL_LAST_NAME             66349 non-null object
# RESIDENTIAL_COMMERCIAL_IND    66349 non-null object
# BOROUGH                       66349 non-null object
# EVICTION_ZIP                  66349 non-null int64
# dtypes: int64(2), object(8)
# memory usage: 5.1+ MB

# %% [markdown]
# ## Clean up the data

# %%
evictions_df['MARSHAL_FIRST_NAME'].value_counts()
# Out:
# Justin        9162
# Henry         6474
# Richard       5889
# Ileana        5839
# Thomas        5559
# Edward        5420
# Danny         5350
# George        4077
# Darlene       3730
# Robert        2515
# Maxine        1871
# Gary          1554
# Alfred        1425
# Ronald        1337
# John           822
# Vadim          804
# Kenneth        769
# Steven         757
# Howard         710
# Frank          547
# Bernard        446
# Charles        394
# Salavatore     384
# Bruce          369
# Jeffrey        145
# Name: MARSHAL_FIRST_NAME, dtype: int64

# %%
# creating a column that has both names of the marshal 
evictions_df['MARSHAL_NAME'] = evictions_df['MARSHAL_FIRST_NAME'] +' '+ evictions_df['MARSHAL_LAST_NAME']

# %%
# dropping the first name and last name columns for a cleaner look
evictions_df.drop(labels = ['MARSHAL_FIRST_NAME', 'MARSHAL_LAST_NAME'], axis = 1, inplace = True)

# %%
evictions_df
# Out:
#       COURT_INDEX_NUMBER  DOCKET_NUMBER        EVICTION_ADDRESS  \
# 0               5743/19B          92057    1226 ROSEDALE AVENUE
# 1              B31724/17          99191      2146 WATSON AVENUE
# 2             K64166/16B          92592          55 WINTHROP ST
# 3              Q62200/18         109351       41-05 74TH STREET
# 4             K071827/17         389794     732 ST MARKS AVENUE
# ...                  ...            ...                     ...
# 66344          Q79426/16          78446     172-10 133RD AVENUE
# 66345              72602          17897  1399 - NOSTRAND AVENUE
# 66346          B65400/16          75064    1935 MONTEREY AVENUE
# 66347         B054192/16         372705        731 UNION AVENUE
# 66348          065282/18          85617      595 ACADEMY STREET
#
#       EVICTION_APT_NUM EXECUTED_DATE RESIDENTIAL_COMMERCIAL_IND    BOROUGH  \
# 0                   3F    07/18/2019                Residential      BRONX
# 1                   1R    05/14/2018                Residential      BRONX
# 2                   5D    03/29/2017                Residential   BROOKLYN
# 3                  1-D    11/15/2018                Residential     QUEENS
# 4                   14    02/13/2018                Residential   BROOKLYN
# ...                ...           ...                        ...        ...
# 66344               8G    10/18/2017                Residential     QUEENS
# 66345              NaN    02/28/2017                 Commercial   BROOKLYN
# 66346               2A    04/14/2017                Residential      BRONX
# 66347               B4    03/21/2017                Residential      BRONX
# 66348          STORE 7    09/27/2018                 Commercial  MANHATTAN
#
#        EVICTION_ZIP         MARSHAL_NAME
# 0             10472      Justin Grossman
# 1             10472       Darlene Barone
# 2             11225       Darlene Barone
# 3             11373       Darlene Barone
# 4             11216        Richard McCoy
# ...             ...                  ...
# 66344         11434        Ileana Rivera
# 66345         11226  Charles Marchisotto
# 66346         10457        Ileana Rivera
# 66347         10455        Richard McCoy
# 66348         10034          Henry Daley
#
# [66349 rows x 9 columns]

# %%
# creating the borough into category type 
evictions_df['BOROUGH'] = evictions_df['BOROUGH'].astype('category')

# %%
# creating the zip code into category type 
evictions_df['EVICTION_ZIP'] = evictions_df['EVICTION_ZIP'].astype('category')

# %%
# covnerting the RESIDENTIAL_COMMERCIAL_IND into category type 
evictions_df['RESIDENTIAL_COMMERCIAL_IND'] = evictions_df['RESIDENTIAL_COMMERCIAL_IND'].astype('category')

# %%
evictions_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66349 entries, 0 to 66348
# Data columns (total 9 columns):
# COURT_INDEX_NUMBER            66349 non-null object
# DOCKET_NUMBER                 66349 non-null int64
# EVICTION_ADDRESS              66349 non-null object
# EVICTION_APT_NUM              55378 non-null object
# EXECUTED_DATE                 66349 non-null object
# RESIDENTIAL_COMMERCIAL_IND    66349 non-null category
# BOROUGH                       66349 non-null category
# EVICTION_ZIP                  66349 non-null category
# MARSHAL_NAME                  66349 non-null object
# dtypes: category(3), int64(1), object(5)
# memory usage: 3.3+ MB

# %% [markdown]
# ## Let's find out which borough has the most evicitons and info on those specific ones

# %%
evictions_df['BOROUGH'].value_counts()
# Out:
# BRONX            22042
# BROOKLYN         18810
# QUEENS           13163
# MANHATTAN        10165
# STATEN ISLAND     2169
# Name: BOROUGH, dtype: int64

# %%
# we can see that the Bronx has the most evictions, let's create a mask and see those values only 
mask1 = evictions_df['BOROUGH'] == 'BRONX'

# %%
# creatins a seperate dataframe for the bronx evicitons 
bronx_evictions = evictions_df[mask1]

# %%
bronx_evictions.head()
# Out:
#    COURT_INDEX_NUMBER  DOCKET_NUMBER      EVICTION_ADDRESS EVICTION_APT_NUM  \
# 0            5743/19B          92057  1226 ROSEDALE AVENUE               3F
# 1           B31724/17          99191    2146 WATSON AVENUE               1R
# 6             5049/18         342917    1462 TAYLOR AVENUE               21
# 9            17929/19         493675    1270 GERARD AVENUE          UNIT 6R
# 17           43881/17          75483    2609 BRIGGS AVENUE               1A
#
#    EXECUTED_DATE RESIDENTIAL_COMMERCIAL_IND BOROUGH EVICTION_ZIP  \
# 0     07/18/2019                Residential   BRONX        10472
# 1     05/14/2018                Residential   BRONX        10472
# 6     04/17/2018                Residential   BRONX        10460
# 9     12/13/2019                Residential   BRONX        10452
# 17    01/11/2018                Residential   BRONX        10458
#
#        MARSHAL_NAME
# 0   Justin Grossman
# 1    Darlene Barone
# 6        Thomas Bia
# 9    Danny Weinheim
# 17      Henry Daley

# %% [markdown]
# ### Trying to see what dates do evictions happen the most in the Bronx

# %%
# we can see the the most evictions happened on 1/10/2018 in the Bronx 
# a trend that we can see is that the 5 top dates of evictions in the Bronx happen towards the end of the year or 
# in the beginning of the year. We can probably see this with other boroughs too 
bronx_evictions['EXECUTED_DATE'].value_counts()
# Out:
# 01/10/2018    73
# 01/09/2018    71
# 11/29/2017    70
# 01/03/2018    68
# 12/12/2017    61
#               ..
# 12/03/2020     1
# 12/21/2018     1
# 07/05/2019     1
# 12/20/2017     1
# 12/30/2019     1
# Name: EXECUTED_DATE, Length: 772, dtype: int64

# %% [markdown]
# ### Let's see which type of property type was most common for evictions in 1/10/2018

# %%
mask2 = bronx_evictions['EXECUTED_DATE'] == '01/10/2018'
mask3 = bronx_evictions['RESIDENTIAL_COMMERCIAL_IND'] == 'Residential'
mask4 = bronx_evictions['RESIDENTIAL_COMMERCIAL_IND'] == 'Commercial'

# %% [markdown]
# #### We can see that 71 were Residenial on 1/10/2018

# %%
bronx_evictions[mask2 & mask3]
# Out:
#       COURT_INDEX_NUMBER  DOCKET_NUMBER  \
# 103              8452/16         321426
# 185           B037514/17         385277
# 255             31843/17         337816
# 1036            56433/17         338831
# 3968           B57218/17         101979
# ...                  ...            ...
# 63716          B36430/17          99968
# 64179           24131/17         472290
# 64746          B42299/17          84611
# 64765           30717/17         471462
# 66303           29661/17           2450
#
#                                   EVICTION_ADDRESS EVICTION_APT_NUM  \
# 103                          220 WEST 167TH STREET               5H
# 185                             1234 STRATFORD AVE               9A
# 255                            872 KINSELLA STREET                2
# 1036                            1463A HICKS STREET                2
# 3968   2322-28 HUGHES AVE AKA 611-617 CRESCENT AVE               17
# ...                                            ...              ...
# 63716                         1235 MORRISON AVENUE               D4
# 64179                       2147 HONEYWELL AVENU E               1B
# 64746                        1870 PELHAM PARKWAY S               3L
# 64765                              3764 BRONX BLVD               4E
# 66303                         1105 MORRISON AVENUE               3L
#
#       EXECUTED_DATE RESIDENTIAL_COMMERCIAL_IND BOROUGH EVICTION_ZIP  \
# 103      01/10/2018                Residential   BRONX        10452
# 185      01/10/2018                Residential   BRONX        10472
# 255      01/10/2018                Residential   BRONX        10462
# 1036     01/10/2018                Residential   BRONX        10469
# 3968     01/10/2018                Residential   BRONX        10458
# ...             ...                        ...     ...          ...
# 63716    01/10/2018                Residential   BRONX        10472
# 64179    01/10/2018                Residential   BRONX        10460
# 64746    01/10/2018                Residential   BRONX        10475
# 64765    01/10/2018                Residential   BRONX        10467
# 66303    01/10/2018                Residential   BRONX        10472
#
#             MARSHAL_NAME
# 103           Thomas Bia
# 185        Richard McCoy
# 255           Thomas Bia
# 1036          Thomas Bia
# 3968      Darlene Barone
# ...                  ...
# 63716     Darlene Barone
# 64179     Danny Weinheim
# 64746      Ileana Rivera
# 64765     Danny Weinheim
# 66303  Vadim Barbarovich
#
# [71 rows x 9 columns]

# %% [markdown]
# #### Only 2 are Commercial properties

# %%
bronx_evictions[mask2 & mask4]
# Out:
#       COURT_INDEX_NUMBER  DOCKET_NUMBER    EVICTION_ADDRESS EVICTION_APT_NUM  \
# 17352          901479/16         462456  3873 ORLOFF AVENUE                *
# 26782          901478/16         462455  3873 ORLOFF AVENUE                *
#
#       EXECUTED_DATE RESIDENTIAL_COMMERCIAL_IND BOROUGH EVICTION_ZIP  \
# 17352    01/10/2018                 Commercial   BRONX        10463
# 26782    01/10/2018                 Commercial   BRONX        10463
#
#          MARSHAL_NAME
# 17352  Danny Weinheim
# 26782  Danny Weinheim

# %%
# these are the Marshal's that had evictions in the bronx on 01/10/2018
bronx_evictions.loc[mask2, 'MARSHAL_NAME'].value_counts()
# Out:
# Danny Weinheim       21
# Thomas Bia           14
# Darlene Barone       13
# Ileana Rivera        10
# Richard McCoy         9
# Vadim Barbarovich     5
# Maxine Chevlowe       1
# Name: MARSHAL_NAME, dtype: int64

# %% [markdown]
# ## Let's see which Marshal had the most evictions in the Bronx altogether

# %%
# we can see that these are the top 5 Marshals who had evictions in Bronx
bronx_evictions['MARSHAL_NAME'].value_counts().nlargest()
# Out:
# Thomas Bia         4080
# Danny Weinheim     3933
# Justin Grossman    2674
# Darlene Barone     2032
# Henry Daley        1873
# Name: MARSHAL_NAME, dtype: int64

# %%
# this is the 5 who had the least amount of evictions in the Bronx 
bronx_evictions['MARSHAL_NAME'].value_counts().nsmallest()
# Out:
# Bruce Kemp        2
# Bernard Blake     4
# Steven Powell     5
# Jeffrey Rose      9
# Gary Rose        21
# Name: MARSHAL_NAME, dtype: int64

# %% [markdown]
# ### The zipcode in the Bronx that had the most evictions

# %%
# Zipcode 10467 has the most evictions within the Bronx 
bronx_evictions['EVICTION_ZIP'].value_counts()
# Out:
# 10467    1835
# 10458    1801
# 10456    1743
# 10453    1668
# 10457    1462
#          ...
# 11230       0
# 11229       0
# 11228       0
# 11226       0
# 11103       0
# Name: EVICTION_ZIP, Length: 223, dtype: int64

# %%
mask5 = bronx_evictions['EVICTION_ZIP'] == 10467
# making a new dataframe for the 10467 zipcode
bronx_10467 = bronx_evictions[mask5]

# %%
# these are the top 10 marhsals that had the most evictions in zipcode 10467
bronx_10467['MARSHAL_NAME'].value_counts().nlargest(10)
# Out:
# Thomas Bia            377
# Danny Weinheim        361
# Justin Grossman       184
# Richard McCoy         138
# Darlene Barone        137
# Ileana Rivera         124
# George Essock, Jr.    111
# Henry Daley           106
# John Villanueva        54
# Maxine Chevlowe        53
# Name: MARSHAL_NAME, dtype: int64

# %% [markdown]
# ## We next do Brooklyn

# %%
evictions_df['BOROUGH'].value_counts()
# Out:
# BRONX            22042
# BROOKLYN         18810
# QUEENS           13163
# MANHATTAN        10165
# STATEN ISLAND     2169
# Name: BOROUGH, dtype: int64

# %%
mask6 = evictions_df['BOROUGH'] == 'BROOKLYN'

# %%
brooklyn_evictions = evictions_df[mask6]

# %%
brooklyn_evictions
# Out:
#       COURT_INDEX_NUMBER  DOCKET_NUMBER             EVICTION_ADDRESS  \
# 2             K64166/16B          92592               55 WINTHROP ST
# 4             K071827/17         389794          732 ST MARKS AVENUE
# 8               70828/17          75589           712A GREENE AVENUE
# 10              53337/17         292042             542 PARKSIDE AVE
# 12              51196/18          24504          939 SARATOGA AVENUE
# ...                  ...            ...                          ...
# 66330          K57962/17          95203            2970 WEST 27TH ST
# 66334           64186/19          96016             280 CROWN STREET
# 66338           82638/15          45815  58 MOTHER GASTON BOU LEVARD
# 66341          93885/17A          74310           1326 BAY RIDGE AVE
# 66345              72602          17897       1399 - NOSTRAND AVENUE
#
#       EVICTION_APT_NUM EXECUTED_DATE RESIDENTIAL_COMMERCIAL_IND   BOROUGH  \
# 2                   5D    03/29/2017                Residential  BROOKLYN
# 4                   14    02/13/2018                Residential  BROOKLYN
# 8                    2    01/31/2018                Residential  BROOKLYN
# 10                  C6    04/24/2017                Residential  BROOKLYN
# 12                  2R    04/27/2018                Residential  BROOKLYN
# ...                ...           ...                        ...       ...
# 66330             1409    10/11/2017                Residential  BROOKLYN
# 66334              B06    07/22/2019                Residential  BROOKLYN
# 66338        3RD FLOOR    02/03/2017                Residential  BROOKLYN
# 66341        2ND FLOOR    05/07/2018                Residential  BROOKLYN
# 66345              NaN    02/28/2017                 Commercial  BROOKLYN
#
#       EVICTION_ZIP         MARSHAL_NAME
# 2            11225       Darlene Barone
# 4            11216        Richard McCoy
# 8            11221          Henry Daley
# 10           11226        George Essock
# 12           11212            Gary Rose
# ...            ...                  ...
# 66330        11224       Darlene Barone
# 66334        11225          Henry Daley
# 66338        11233      Justin Grossman
# 66341        11219      Justin Grossman
# 66345        11226  Charles Marchisotto
#
# [18810 rows x 9 columns]

# %%
# we can see that the date where there were the most evictions in Brooklyn is 1/18/17
brooklyn_evictions['EXECUTED_DATE'].value_counts()
# Out:
# 01/18/2017    74
# 01/16/2019    65
# 01/04/2017    64
# 09/05/2018    62
# 06/01/2018    61
#               ..
# 12/30/2019     1
# 11/13/2020     1
# 12/20/2017     1
# 12/07/2020     1
# 12/31/2018     1
# Name: EXECUTED_DATE, Length: 777, dtype: int64

# %%
mask7 = brooklyn_evictions['EXECUTED_DATE'] == '01/18/2017'
mask8 = brooklyn_evictions['RESIDENTIAL_COMMERCIAL_IND'] == 'Residential'
mask9 = brooklyn_evictions['RESIDENTIAL_COMMERCIAL_IND'] == 'Commercial'

# %%
brooklyn_evictions[mask7 & mask8]
# Out:
#       COURT_INDEX_NUMBER  DOCKET_NUMBER      EVICTION_ADDRESS  \
# 499             94092/16          58626   2065 HENDRICKSON ST
# 1409           K88972/16          74165       510 80TH STREET
# 3775          13980/15-2           4114      2630 LINDEN BLVD
# 6836            80716/16          65913         1620 AVENUE I
# 6951           86160/16B          57764   2902 CORTELYOU ROAD
# ...                  ...            ...                   ...
# 61667          K94341/16          75141    649 VERMONT STREET
# 62223           90988/16          57969      499 OCEAN AVENUE
# 63577          K79728/16          73953  901 WASHINGTON AVENU
# 66206          K98868/15          88662    2-12 OAKLAND PLACE
# 66321           91841/16          59414   671 BRADFORD STREET
#
#       EVICTION_APT_NUM EXECUTED_DATE RESIDENTIAL_COMMERCIAL_IND   BOROUGH  \
# 499       ENTIRE HOUSE    01/18/2017                Residential  BROOKLYN
# 1409               3-A    01/18/2017                Residential  BROOKLYN
# 3775                1C    01/18/2017                Residential  BROOKLYN
# 6836                C5    01/18/2017                Residential  BROOKLYN
# 6951                A3    01/18/2017                Residential  BROOKLYN
# ...                ...           ...                        ...       ...
# 61667               3F    01/18/2017                Residential  BROOKLYN
# 62223               2F    01/18/2017                Residential  BROOKLYN
# 63577               1M    01/18/2017                Residential  BROOKLYN
# 66206              4-J    01/18/2017                Residential  BROOKLYN
# 66321              1ST    01/18/2017                Residential  BROOKLYN
#
#       EVICTION_ZIP     MARSHAL_NAME
# 499          11234  Justin Grossman
# 1409         11209    Ileana Rivera
# 3775         11208     Jeffrey Rose
# 6836         11230      Henry Daley
# 6951         11226  Justin Grossman
# ...            ...              ...
# 61667        11207    Ileana Rivera
# 62223        11226  Justin Grossman
# 63577        11225    Ileana Rivera
# 66206        11226   Darlene Barone
# 66321        11207    Howard Schain
#
# [71 rows x 9 columns]

# %%
brooklyn_evictions[mask7 & mask9]
# Out:
#       COURT_INDEX_NUMBER  DOCKET_NUMBER      EVICTION_ADDRESS  \
# 160             78990/16          58148  3038 ATLANTIC AVENUE
# 40409          K80917/16          93593           462 36TH ST
# 48182           68660/16         165866   467 TROUTMAN STREET
#
#       EVICTION_APT_NUM EXECUTED_DATE RESIDENTIAL_COMMERCIAL_IND   BOROUGH  \
# 160    3RD FLOOR AKA E    01/18/2017                 Commercial  BROOKLYN
# 40409          UNIT 3A    01/18/2017                 Commercial  BROOKLYN
# 48182          UNIT 26    01/18/2017                 Commercial  BROOKLYN
#
#       EVICTION_ZIP     MARSHAL_NAME
# 160          11208  Justin Grossman
# 40409        11232   Darlene Barone
# 48182        11237  Alfred Locascio

# %%
# These are the number of evictions each Marshal had on 01/18/2017
brooklyn_evictions.loc[mask7, 'MARSHAL_NAME'].value_counts()
# Out:
# Justin Grossman        21
# Ileana Rivera          20
# Henry Daley            11
# Alfred Locascio         9
# Gary Rose               3
# Darlene Barone          3
# Richard Capuano         2
# Jeffrey Rose            2
# Howard Schain           1
# Charles Marchisotto     1
# Robert Solimine         1
# Name: MARSHAL_NAME, dtype: int64
